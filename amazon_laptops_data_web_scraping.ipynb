26sr%3D1-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1%26m%3DA2R87W6XPBZ1J4%26SPES%3D1"><h2 aria-label='Sponsored Ad - HP Flagship 14" HD Laptop with 1 Year Office 365 | 16GB RAM | 1.22TB Storage(64GB EMMC &amp; 160GB Docking Station Set &amp; 1TB Cloud Storage) | Intel 4-Core Processor | Webcam | Win 11s | Whit
# ...

# %%
link = links[0].get('href')

# %%
product_link = "https://amazon.com" + link
product_link
# Out:
# 'https://amazon.com/sspa/click?ie=UTF8&spc=MTo0MzU2NjY4NTk0MjEwNzkxOjE3MzM4MzY4NjI6c3BfYXRmOjMwMDQ1MzY2MDIzMTIwMjo6MDo6&url=%2FHP-Flagship-Storage-Docking-Processor%2Fdp%2FB0DHXL7N1T%2Fref%3Dsr_1_1_sspa%3Fcrid%3D247WJYZXQZ1Y5%26dib%3DeyJ2IjoiMSJ9.6redjtGG6pggSXUY23uRhsMwVQxmoVEPDnb-4u1M5hsHQq690JE0QSx0BH8qFSvOmc3MzEqbBaYioNVtuKkfcScFfvlmjmSYgNwYGZu4oqkO29C0PgZQuXsjbjcohw3cTlIjgdZb-u-Q3fDprejgOOLTAQW4EcQnQIU_QoLYwjm-XnxOLB1Pn-XRjwDrS5Kz.0Ru6jA67nP_tVJJW4jL9YOQGWonBO27IEpC4QxaDyWg%26dib_tag%3Dse%26keywords%3Dlaptops%26psr%3DEY17%26qid%3D1733836862%26s%3Dtodays-deals%26sprefix%3Dlaptops%252Ctodays-deals%252C337%26sr%3D1-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1%26m%3DA2R87W6XPBZ1J4%26SPES%3D1'

# %%
new_webpage = requests.get(product_link, headers=HEADERS)

# %%
new_webpage
# Out:
# <Response [200]>

# %%
new_soup = BeautifulSoup(new_webpage.content, "html.parser")

# %%
new_soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
new_soup.find("span", attrs={"id": "productTitle"})
# Out:
# <span class="a-size-large product-title-word-break" id="productTitle">        HP Flagship 14" HD Laptop with 1 Year Office 365 | 16GB RAM | 1.22TB Storage(64GB EMMC &amp; 160GB Docking Station Set &amp; 1TB Cloud Storage) | Intel 4-Core Processor | Webcam | Win 11s | White       </span>

# %%
new_soup.find("span", attrs={"id": "productTitle"}).text
# Out:
# '        HP Flagship 14" HD Laptop with 1 Year Office 365 | 16GB RAM | 1.22TB Storage(64GB EMMC & 160GB Docking Station Set & 1TB Cloud Storage) | Intel 4-Core Processor | Webcam | Win 11s | White       '

# %%
new_soup.find("span", attrs={"id": "productTitle"}).text.strip()
# Out:
# 'HP Flagship 14" HD Laptop with 1 Year Office 365 | 16GB RAM | 1.22TB Storage(64GB EMMC & 160GB Docking Station Set & 1TB Cloud Storage) | Intel 4-Core Processor | Webcam | Win 11s | White'

# %%
new_soup.find("span", attrs={"class": "a-price a-text-price a-size-medium"})
# Out:
# <span class="a-price a-text-price a-size-medium" data-a-color="price" data-a-size="b"><span class="a-offscreen">$279.00</span><span aria-hidden="true">$279.00</span></span>

# %%
new_soup.find("span", attrs={"class": "a-price a-text-price a-size-medium"}).text.strip()
# Out:
# '$279.00$279.00'

# %%
new_soup.find("span", attrs={"class": "a-price a-text-price a-size-medium"}).find("span", attrs={"class": "a-offscreen"}).text
# Out:
# '$279.00'

# %%
new_soup.find("span", attrs={"class": "a-icon-alt"}).text
# Out:
# '4.5 out of 5 stars'

# %%
# function

def get_title(soup):
    try:
        title = soup.find("span", attrs={"id": "productTitle"}).text.strip()
    except:
        title = None
    return title

def get_price(soup):
    try:
        price = soup.find("span", attrs={"class": "a-price a-text-price a-size-medium"}).find("span", attrs={"class": "a-offscreen"}).text.strip()
    except:
        price = None
    return price

def get_rating(soup):
    try:
        review = soup.find("span", attrs={"class": "a-icon-alt"}).text
    except:
        review = None
    return review

# %%
# HEADERS = 

URL = 'https://www.amazon.com/s?k=laptops&i=todays-deals&crid=247WJYZXQZ1Y5&sprefix=laptops%2Ctodays-deals%2C337&ref=nb_sb_noss_1'

webpage = requests.get(URL, headers=HEADERS)

soup = BeautifulSoup(webpage.content, "html.parser")

links = soup.find_all("a", attrs={"class": "a-link-normal s-line-clamp-2 s-link-style a-text-normal"})

links_list = []

for link in links:
    links_list.append(link.get('href'))

d = {"Title": [], "Price": [], "Rating": []}


for link in links_list:
    product_link = "https://amazon.com" + link
    new_webpage = requests.get(product_link, headers=HEADERS)
    new_soup = BeautifulSoup(new_webpage.content, "html.parser")
    
    d["Title"].append(get_title(new_soup))
    d["Price"].append(get_price(new_soup))
    d["Rating"].append(get_rating(new_soup))

amazon_df = pd.DataFrame(d)

# %%
amazon_df
# Out:
#                                                 Title    Price  \
# 0   16.0-inch Laptop, 16GB DDR4 512GB SSD, Windows...  $389.99
# 1   Laptop Computer,15.6In Windows 11 Pro Laptop w...  $359.99
# 2   HP 14" Ultral Light Laptop for Students and Bu...  $212.00
# 3   16.0-inch Laptop, 16GB DDR4 512GB SSD, Windows...  $389.99
# 4   2024 Newest Gaming Laptop, 16.1-inch FHD Displ...  $599.98
# 5   HP Flagship 14" HD Laptop with 1 Year Office 3...  $279.00
# 6   Laptop, 15.6 Inch Laptops, Windows 11 Computer...  $329.93
# 7   ACEMAGIC 2024 Newest Gaming Laptop, 16.1-inch ...  $599.98
# 8   AOC Gaming Laptop with AMD Ryzen 7 Processor(8...  $579.98
# 9   ASUS 14" FHD Laptop, Intel Celeron N4500 Proce...  $179.10
# 10  ACEMAGIC Laptop, Newest Windows 11 Laptop Comp...  $359.89
# 11  2024 Newest Gaming Laptop, 16.1-inch FHD Displ...  $599.98
# 12  Laptop Computer Windows Laptop 16GB DDR4 512GB...  $359.99
# 13  acer Nitro V Gaming Laptop | AMD Ryzen 5 7535H...     None
# ...

# %%
amazon_df.isnull().sum()
# Out:
# Title     0
# Price     1
# Rating    0
# dtype: int64

# %%
# save the data
amazon_df.to_csv("amazon_laptops.csv", index=False)
